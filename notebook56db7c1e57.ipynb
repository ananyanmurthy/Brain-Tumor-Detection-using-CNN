# %% [markdown]
# # Import Statements

# %%
import os
import keras 
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('dark_background')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
import keras
print(keras.backend.backend())
# Out:
# tensorflow

# %% [markdown]
# # One Hot Encoding the Target Classes

# %%
encoder = OneHotEncoder()
encoder.fit([[0], [1]]) 

# 0 - Tumor
# 1 - Normal
# Out:
# OneHotEncoder()

# %% [markdown]
# # Creating 3 Important Lists --
# 1. data list for storing image data in numpy array form
# 2. paths list for storing paths of all images
# 3. result list for storing one hot encoded form of target class whether normal or tumor

# %%
# This cell updates result list for images with tumor

data = []
paths = []
result = []

for r, d, f in os.walk(r'../input/brain-mri-images-for-brain-tumor-detection/yes'):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[0]]).toarray())

# %%
# This cell updates result list for images without tumor

paths = []
for r, d, f in os.walk(r"../input/brain-mri-images-for-brain-tumor-detection/no"):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[1]]).toarray())

# %%
data = np.array(data)
data.shape
# Out:
# (139, 128, 128, 3)

# %%
result = np.array(result)
result = result.reshape(139,2)

# %% [markdown]
# # Splitting the Data into Training & Testing

# %%
x_train,x_test,y_train,y_test = train_test_split(data, result, test_size=0.2, shuffle=True, random_state=0)

# %% [markdown]
# # Model Building

# %% [markdown]
# Batch normalization is a technique for training very deep neural networks that standardizes the inputs to a layer for each mini-batch. This has the effect of stabilizing the learning process and dramatically reducing the number of training epochs required to train deep networks.

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(2, 2), input_shape=(128, 128, 3), padding = 'Same'))
model.add(Conv2D(32, kernel_size=(2, 2),  activation ='relu', padding = 'Same'))


model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))

model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))

model.compile(loss = "categorical_crossentropy", optimizer='Adamax')
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 128, 128, 32)      416
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 32)      4128
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 128, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 64)        8256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 64)        16448
# ...

# %%
y_train.shape
# Out:
# (111, 2)

# %%
history = model.fit(x_train, y_train, epochs = 30, batch_size = 40, verbose = 1,validation_data = (x_test, y_test))
# Out:
# Epoch 1/30
# 3/3 [==============================] - 3s 958ms/step - loss: 80.9364 - val_loss: 63.5214
# Epoch 2/30
# 3/3 [==============================] - 3s 912ms/step - loss: 26.0171 - val_loss: 29.8385
# Epoch 3/30
# 3/3 [==============================] - 3s 1s/step - loss: 12.0631 - val_loss: 12.4548
# Epoch 4/30
# 3/3 [==============================] - 3s 893ms/step - loss: 5.8633 - val_loss: 21.1585
# Epoch 5/30
# 3/3 [==============================] - 3s 885ms/step - loss: 4.8403 - val_loss: 12.6879
# Epoch 6/30
# 3/3 [==============================] - 3s 881ms/step - loss: 2.6444 - val_loss: 6.5082
# Epoch 7/30
# 3/3 [==============================] - 3s 895ms/step - loss: 2.1685 - val_loss: 5.4425
# Epoch 8/30
# 3/3 [==============================] - 3s 872ms/step - loss: 0.7014 - val_loss: 9.5110
# Epoch 9/30
# 3/3 [==============================] - 3s 846ms/step - loss: 0.9837 - val_loss: 9.6849
# Epoch 10/30
# ...

# %% [markdown]
# # Plotting Losses

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Test', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# # Just Checking the Model

# %%
def names(number):
    if number==0:
        return 'Its a Tumor'
    else:
        return 'No, Its not a tumor'

# %%
from matplotlib.pyplot import imshow
img = Image.open(r"/kaggle/input/brain-mri-images-for-brain-tumor-detection/no/1 no.jpeg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence This Is ' + name(classification))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-e1bd91bef70b> in <module>
#       2 img = Image.open(r"/kaggle/input/brain-mri-images-for-brain-tumor-detection/no/1 no.jpeg")
#       3 x = np.array(img.resize((128,128)))
# ----> 4 x = x.reshape(1,128,128,3)
#       5 res = model.predict_on_batch(x)
#       6 classification = np.where(res == np.amax(res))[1][0]
#
# ValueError: cannot reshape array of size 16384 into shape (1,128,128,3)

# %%
from matplotlib.pyplot import imshow
img = Image.open(r"/kaggle/input/brain-mri-images-for-brain-tumor-detection/yes/Y10.jpg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence This Is ' + name(classification))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-193aad2e9a1b> in <module>
#       2 img = Image.open(r"/kaggle/input/brain-mri-images-for-brain-tumor-detection/yes/Y10.jpg")
#       3 x = np.array(img.resize((128,128)))
# ----> 4 x = x.reshape(1,128,128,3)
#       5 res = model.predict_on_batch(x)
#       6 classification = np.where(res == np.amax(res))[1][0]
#
# ValueError: cannot reshape array of size 16384 into shape (1,128,128,3)

# %% [markdown]
# # Thats It !!

# %%
from matplotlib.pyplot import imshow
img = Image.open(r"/kaggle/input/brain-mri-images-for-brain-tumor-detection/yes/Y244.JPG")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence This Is A ' + names(classification))
# Out:
# 52.2020697593689% Confidence This Is A Its a Tumor

# %%
from matplotlib.pyplot import imshow
img = Image.open(r"/kaggle/input/brain-mri-images-for-brain-tumor-detection/no/5 no.jpg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence This Is ' + names(classification))
# Out:
# 99.99568462371826% Confidence This Is No, Its not a tumor
